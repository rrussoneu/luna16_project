# %%
# %cd /content/drive/My\ Drive/luna_project
# Out:
# /content/drive/My Drive/luna_project

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 60.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.1 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.23.1 which is incompatible.
# ...

# %%
from log_util import logging
from util import importstr

log = logging.getLogger('nb')

# %%
import os

def run(app, *argv):
  argv = list(argv)
  #argv.insert(0, '--num-workers={}'.format(os.cpu_count()))
  argv.insert(0, '--num-workers={}'.format(4))
  log.info("Running: {}({!r}).main()".format(app, argv))

  app_cls = importstr(*app.rsplit('.',1))
  app_cls(argv).main()

  log.info("Finished: {}.{!r}).main()".format(app, argv))

# %%
run('prepcache_cls.LunaPrepCacheApp')
# Out:
# 2024-05-28 16:29:38,439 INFO     pid:1519 nb:007:run Running: prepcache_cls.LunaPrepCacheApp(['--num-workers=4']).main()
# 2024-05-28 16:29:53,411 INFO     pid:1519 prepcache_cls:048:main Starting LunaPrepCacheApp, Namespace(batch_size=1024, num_workers=4)
# 2024-05-28 16:39:20,717 INFO     pid:1519 dsets_classification:109:getCandidateInfoList Num invalid: 126
# 2024-05-28 16:39:22,277 INFO     pid:1519 dsets_classification:309:__init__ <dsets_classification.LunaDataset object at 0x7c4651be2b60>: 495068 training samples, 494012 neg, 1056 pos, unbalanced ratio
# 2024-05-28 16:39:22,279 WARNING  pid:1519 util:099:enumerateWithEstimate Stuffing cache ----/484, starting
# 2024-05-28 16:47:45,927 INFO     pid:1519 util:116:enumerateWithEstimate Stuffing cache   16/484, done at 2024-05-28 20:46:28, 4:05:21
# 2024-05-28 17:07:43,756 INFO     pid:1519 util:116:enumerateWithEstimate Stuffing cache   64/484, done at 2024-05-28 20:10:30, 3:29:22
# ...

# %%
run('retrain_cls.ClassificationTrainingApp', f'--epochs=30', 'nodule-nonnodule')
# Out:
# 2024-05-28 20:33:18,682 INFO     pid:3111 nb:007:run Running: retrain_cls.ClassificationTrainingApp(['--num-workers=4', '--epochs=30', 'nodule-nonnodule']).main()
# 2024-05-28 20:33:26,056 INFO     pid:3111 numexpr.utils:148:_init_num_threads Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-05-28 20:33:26,058 INFO     pid:3111 numexpr.utils:161:_init_num_threads NumExpr defaulting to 8 threads.
# 2024-05-28 20:38:14,472 INFO     pid:3111 retrain_cls:143:initModel Using CUDA; 1 devices.
# 2024-05-28 20:38:16,163 INFO     pid:3111 retrain_cls:210:main Starting ClassificationTrainingApp, Namespace(batch_size=32, num_workers=4, epochs=30, dataset='LunaDataset', model='LunaModel', malignant=False, finetune='', finetune_depth=1, tb_prefix='Luna_Runs/cls', comment='nodule-nonnodule')
# ---------------------------------------------------------------------------
# ...
